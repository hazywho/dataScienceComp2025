# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\zanyi\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\zanyi\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
df = pd.read_csv(r"SATSCORE.csv")
df.head()
# Out:
#    Year  M_verbal  F_verbal  M_math  F_math  A_verbal  A_math  M_averages  \
# 0  1967       540       545     535     495       543     516         538
# 1  1968       541       543     533     497       543     516         537
# 2  1969       536       543     534     498       540     517         535
# 3  1970       536       538     531     493       537     512         534
# 4  1971       531       534     529     494       532     513         530
#
#    F_averages  A_averages
# 0         520         529
# 1         520         528
# 2         520         528
# 3         516         524
# 4         514         522

# %%
print(df.shape)
df.isna().sum()
# Out:
# (35, 10)
# Year          0
# M_verbal      0
# F_verbal      0
# M_math        0
# F_math        0
# A_verbal      0
# A_math        0
# M_averages    0
# F_averages    0
# A_averages    0
# dtype: int64

# %%
df_sorted=df.sort_values("Year")
df_sorted
# Out:
#     Year  M_verbal  F_verbal  M_math  F_math  A_verbal  A_math  M_averages  \
# 0   1967       540       545     535     495       543     516         538
# 1   1968       541       543     533     497       543     516         537
# 2   1969       536       543     534     498       540     517         535
# 3   1970       536       538     531     493       537     512         534
# 4   1971       531       534     529     494       532     513         530
# 5   1972       531       529     527     489       530     509         529
# 6   1973       523       521     525     489       523     506         524
# 7   1974       524       520     524     488       521     505         524
# 8   1975       515       509     518     479       512     498         516
# 9   1976       511       508     520     475       509     497         516
# 10  1977       509       505     520     474       507     496         514
# ...

# %%
fig,ax = plt.subplots(1,1)

ax.plot(df_sorted["Year"],df_sorted["M_averages"],linestyle="-",color="blue",label="male")
ax.plot(df_sorted["Year"],df_sorted["F_averages"],linestyle="-",color="orange",label="female")
plt.ylabel("Average score")
plt.xlabel("Year")
plt.title("Average SAT score over the years")
plt.legend()

plt.savefig(fname="satScoreOverYears.jpg",dpi=300)

# %%
fig,ax = plt.subplots(1,1)

ax.plot(df_sorted["Year"],df_sorted["M_averages"],linestyle="-",color="blue",label="male")
ax.plot(df_sorted["Year"],df_sorted["F_averages"],linestyle="-",color="orange",label="female")
plt.ylabel("Average score")
plt.xlabel("Year")
plt.title("Average SAT score over the years")
plt.legend()

coef1 = np.polyfit(df_sorted["Year"],df_sorted["M_averages"],1)
poly1d_fn = np.poly1d(coef1) 
ax.plot(df_sorted["Year"],df_sorted["M_averages"], 'yo', df_sorted["Year"], poly1d_fn(df_sorted["Year"]), '--k')

coef1 = np.polyfit(df_sorted["Year"],df_sorted["F_averages"],1)
poly1d_fn = np.poly1d(coef1) 
ax.plot(df_sorted["Year"],df_sorted["F_averages"], 'yo', df_sorted["Year"], poly1d_fn(df_sorted["Year"]), '--k')
plt.savefig(fname="satScoreOverYearsLR.jpg",dpi=300)

# %%
print(max(df.M_averages))
print(max(df.F_averages))
# Out:
# 538
# 520

# %%
df.loc[df['M_averages'] == max(df.M_averages)]
df.loc[df['F_averages'] == max(df.F_averages)]
# Out:
#    Year  M_verbal  F_verbal  M_math  F_math  A_verbal  A_math  M_averages  \
# 0  1967       540       545     535     495       543     516         538
# 1  1968       541       543     533     497       543     516         537
# 2  1969       536       543     534     498       540     517         535
#
#    F_averages  A_averages
# 0         520         529
# 1         520         528
# 2         520         528
